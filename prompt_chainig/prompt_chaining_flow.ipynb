# %%
from langgraph.graph import StateGraph,START,END
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation"
) 

model = ChatHuggingFace(llm = llm)

# %%
class Blogstate(TypedDict):
    title : str
    outline : str
    content : str

# %%
def create(state : Blogstate) -> Blogstate:
    title = state['title']

    prompt = f"Generate an outline for a blog on the topic {title}"

    result = model.invoke(prompt).content

    state['outline'] = result

    return state

# %%
def create_blog(state: Blogstate)-> Blogstate:
    title = state['title']
    outline = state['outline']

    prompt = f"write a detailed blog on the title {title} using the following outline \n {outline}"

    blog_out = model.invoke(prompt).content

    state['content'] = blog_out

    return state

# %%
graph = StateGraph(Blogstate)

graph.add_node('vivaan' , create)
graph.add_node('utke', create_blog)

graph.add_edge(START, 'vivaan')
graph.add_edge('vivaan' , 'utke')
graph.add_edge('utke', END)

workflow = graph.compile()

# %%
initial_state = {'title' : 'AI will impact on human'}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# **The Impact of AI on Humans: A Comprehensive Guide**
#
# As we continue to move forward into the digital age, one thing is becoming increasingly clear: Artificial Intelligence (AI) is transforming every aspect of our lives. From the way we work and interact with each other to the way we learn and maintain our physical and mental health, AI is leaving an indelible mark on human society. In this comprehensive guide, we'll explore the various impacts of AI on humans, examining both the benefits and the risks associated with this emerging technology.
#
# **I. Introduction**
#
# Artificial Intelligence has been a growing presence in modern life for several decades, from the earliest AI-powered chatbots to the sophisticated AI systems of today. With the advent of machine learning, deep learning, and other advanced AI technologies, the possibilities for AI have expanded exponentially. Today, AI is a ubiquitous force in our daily lives, influencing everything from the way we communicate with our smartphones to the way we navigate complex financial transactions. As AI continues to evolve and become more integrated into our lives, it's essential to understand the far-reaching impacts it will have on human existence.
#
# **II. Changes in the Workforce**
#
# One of the most significant areas where AI will have an impact on humans is in the workforce. As AI technologies become more advanced, they will inevitably displace certain jobs, particularly those involving repetitive tasks. According to a report by the World Economic Forum, up to 75 million jobs could be displaced by AI by 2022. However, this does not mean that AI will result in widespread unemployment. Rather, it will create new job opportunities in emerging fields such as AI development, data science, and cybersecurity. Additionally, AI will enhance existing jobs, making them more efficient and productive.
#
# *   **Automation and Job Displacement**
#     AI will replace certain jobs, especially those involving repetitive tasks. Examples of industries where AI has already made significant inroads include customer service and transportation.
# *   **New Job Opportunities**
#     Emerging fields that AI will create include AI development, data science, and cybersecurity. AI will also enhance existing jobs, making them more efficient and productive.
#
# **III. Impact on Education**
#
# Another area where AI will have a significant impact on humans is in education. AI-powered adaptive learning systems will tailor education to individual needs and abilities, creating a more personalized learning experience. This will be especially beneficial for students with disabilities, as AI can adjust the learning experience to meet their unique requirements.
#
# *   **Personalized Learning**
#     AI-powered adaptive learning systems will tailor education to
